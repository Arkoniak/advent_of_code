# %% [markdown]
# ## Part 1

# %%
struct Maze
    m::Array{Char, 2}
end

Maze(s::Vector{T}) where T <: String = Maze(hcat(collect.(s)...))

find_element(m::Maze, el::Char) = get(CartesianIndices(m.m)[m.m .== el], 1, nothing)
find_elements(m::Maze, els) = [(x, find_element(m, x)) for x in els if find_element(m, x) != nothing]
mkeys(m::Maze) = Dict(find_elements(m, 'a':'z'))
doors(m::Maze) = Dict(find_elements(m, 'A':'Z'))
hero(m::Maze) = find_element(m, '@')

function neighbours(m::Maze, l)
    dirs = CartesianIndex.([(0, 1), (1, 0), (0, -1), (-1, 0)])
    [l + d for d in dirs[[m.m[l + d] != '#' for d in dirs]]]
end

function floodfill(m::Maze, start)
    arr = fill(-1, size(m.m)...)
    arr[start] = 0
    acc = [start]
    while !isempty(acc)
        loc = popfirst!(acc)
        for n in neighbours(m, loc)
            if arr[n] == -1 || arr[n] > arr[loc] + 1
                arr[n] = arr[loc] + 1
                push!(acc, n)
            end
        end
    end
    
    arr
end

function get_door_keys(maze::Maze, arr, start, finish)
    res = Char[]
    current = start
    dirs = CartesianIndex.([(0, 1), (1, 0), (0, -1), (-1, 0)])
    while current != finish
        for d in dirs
            if arr[current + d] + 1 == arr[current]
                current = current + d
                if maze.m[current] in collect('A':'Z') push!(res, lowercase(maze.m[current])) end
                break
            end
        end
    end
                
    res
end

function build_info(m::Maze)
    res = Dict()
    for (k, loc) in mkeys(m)
        arr = floodfill(m, loc)
        res[k] = Dict([(k1, (arr[v1], get_door_keys(m, arr, v1, loc))) for (k1, v1) in mkeys(m)])
    end
    
    arr = floodfill(m, hero(m))
    res['@'] = Dict([(k1, (arr[v1], get_door_keys(m, arr, v1, hero(m)))) for (k1, v1) in mkeys(m)])
    
    res
end
# Out:
# build_info (generic function with 1 method)

# %%
function part1(inp = "input.txt")
    m = Maze(readlines(inp))
    nkeys = length(mkeys(m)) + 1
    info = build_info(m)
    acc = [(['@'], 0)]
    res = []
    min_score = -1
    while !isempty(acc)
#        sort!(acc, by = x -> -x[2]/length(x[1]))
        
        ks, score = pop!(acc)
#        println(join(ks), " : ", score)
        if length(ks) == nkeys 
            if min_score < 0 || score < min_score min_score = score end
            println(join(ks), " : ", score)
            push!(res, (join(ks), score))
        end
        for (k, v) in info[ks[end]]
            if !(k in ks)
                if min_score > 0 && (score + v[1]) > min_score continue end
                if length(intersect(v[2], ks)) == length(v[2])
                    push!(acc, (vcat(ks, k), score + v[1]))
                end
            end
        end
    end
    
    return res
end
# Out:
# part1 (generic function with 2 methods)

# %%
m = Maze(readlines("test2.txt"))
println.(readlines("test2.txt"))
part1("test2.txt")
# Out:
# #################
# #i.G..c...e..H.p#
# ########.########
# #j.A..b...f..D.o#
# ########@########
# #k.E..a...g..B.n#
# ########.########
# #l.F..d...h..C.m#
# #################
# @bgcmaijhpekdofln : 176
# @bgcmaijhpekdofnl : 174
# @bgcmaijhpekdfonl : 174
# @bgcmaijhpekdnofl : 174
# @bgcmaijhpekdnfol : 174
# @bgcmaijhpekfldno : 174
# @bgcmaijhpekfdlno : 174
# @bgcmaijhpekfnldo : 174
# @bgcmaijhpekfndlo : 174
# @bgcmaijhpekndofl : 174
# @bgcmaijhpekndfol : 174
# @bgcmaijhpeknfldo : 174
# @bgcmaijhpeknfdlo : 174
# @bgcmaijhpedkofnl : 174
# @bgcmaijhpedkfonl : 174
# @bgcmaijhpedknofl : 174
# @bgcmaijhpedknfol : 174
# @bgcmaijhpedofknl : 174
# @bgcmaijhpedofnkl : 174
# @bgcmaijhpedfoknl : 174
# @bgcmaijhpedfonkl : 174
# @bgcmaijhpednkofl : 174
# @bgcmaijhpednkfol : 174
# @bgcmaijhpednofkl : 174
# @bgcmaijhpednfokl : 174
# @bgcmaijhpefldkon : 172
# @bgcmaijhpefldkno : 170
# @bgcmaijhpefldnko : 170
# @bgcmaijhpefkldno : 170
# @bgcmaijhpefkdlno : 170
# @bgcmaijhpefknldo : 170
# @bgcmaijhpefkndlo : 170
# @bgcmaijhpefdlkno : 170
# @bgcmaijhpefdlnko : 170
# @bgcmaijhpefnldko : 170
# @bgcmaijhpefnkldo : 170
# @bgcmaijhpefnkdlo : 170
# @bgcmaijhpefndlko : 170
# @bgcmaijhepfldkno : 170
# @bgcmaijhepfldnko : 170
# @bgcmaijhepfkldno : 170
# @bgcmaijhepfkdlno : 170
# @bgcmaijhepfknldo : 170
# @bgcmaijhepfkndlo : 170
# @bgcmaijhepfdlkno : 170
# @bgcmaijhepfdlnko : 170
# @bgcmaijhepfnldko : 170
# @bgcmaijhepfnkldo : 170
# @bgcmaijhepfnkdlo : 170
# @bgcmaijhepfndlko : 170
# @bgcmaijhdpekofnl : 170
# @bgcmaijhdpekfonl : 170
# @bgcmaijhdpeknofl : 170
# @bgcmaijhdpeknfol : 170
# @bgcmaijhdpeoflkn : 168
# @bgcmaijhdpeoflnk : 168
# @bgcmaijhdpeofkln : 168
# @bgcmaijhdpeofknl : 166
# @bgcmaijhdpeofnkl : 166
# @bgcmaijhdpefoknl : 166
# @bgcmaijhdpefonkl : 166
# @bgcmaijhdofpeknl : 166
# @bgcmaijhdofpenkl : 166
# @bgcmaijhdofepknl : 166
# @bgcmaijhdofepnkl : 166
# @bgcmaijhdepofknl : 166
# @bgcmaijhdepofnkl : 166
# @bgcmaijhdepfoknl : 166
# @bgcmaijhdepfonkl : 166
# @bgcmaijhdfopeknl : 166
# @bgcmaijhdfopenkl : 166
# @bgcmaijhdfoepknl : 166
# @bgcmaijhdfoepnkl : 166
# @bgcmaijhdnpeofkl : 166
# @bgcmaijhdnpefokl : 166
# @bgcmaijhdnofpekl : 166
# @bgcmaijhdnofepkl : 166
# @bgcmaijhdnepofkl : 166
# @bgcmaijhdnepfokl : 166
# @bgcmaijhdnfopekl : 166
# @bgcmaijhdnfoepkl : 166
# @bgcmaijdhpeofknl : 166
# @bgcmaijdhpeofnkl : 166
# @bgcmaijdhpefoknl : 166
# @bgcmaijdhpefonkl : 166
# @bgcmaijdhofpeknl : 166
# @bgcmaijdhofpenkl : 166
# @bgcmaijdhofepknl : 166
# @bgcmaijdhofepnkl : 166
# @bgcmaijdhepofknl : 166
# @bgcmaijdhepofnkl : 166
# @bgcmaijdhepfoknl : 166
# @bgcmaijdhepfonkl : 166
# @bgcmaijdhfopeknl : 166
# @bgcmaijdhfopenkl : 166
# @bgcmaijdhfoepknl : 166
# @bgcmaijdhfoepnkl : 166
# @bgcmaijdhnpeofkl : 166
# @bgcmaijdhnpefokl : 166
# @bgcmaijdhnofpekl : 166
# @bgcmaijdhnofepkl : 166
# @bgcmaijdhnepofkl : 166
# @bgcmaijdhnepfokl : 166
# @bgcmaijdhnfopekl : 166
# @bgcmaijdhnfoepkl : 166
# @bgcmaijfldhpekno : 166
# @bgcmaijfldhpeokn : 164
# @bgcmaijfldhpeonk : 164
# @bgcmaijfldhopekn : 164
# @bgcmaijfldhopenk : 164
# @bgcmaijfldhoepkn : 164
# @bgcmaijfldhoepnk : 164
# @bgcmaijfldhepokn : 164
# @bgcmaijfldheponk : 164
# @bgcmaijfldhnpeok : 164
# @bgcmaijfldhnopek : 164
# @bgcmaijfldhnoepk : 164
# @bgcmaijfldhnepok : 164
# @bgcmaijfhldpeokn : 164
# @bgcmaijfhldpeonk : 164
# @bgcmaijfhldopekn : 164
# @bgcmaijfhldopenk : 164
# @bgcmaijfhldoepkn : 164
# @bgcmaijfhldoepnk : 164
# @bgcmaijfhldepokn : 164
# @bgcmaijfhldeponk : 164
# @bgcmaijfhldnpeok : 164
# @bgcmaijfhldnopek : 164
# @bgcmaijfhldnoepk : 164
# @bgcmaijfhldnepok : 164
# @bgcmaijfhdlpeokn : 164
# @bgcmaijfhdlpeonk : 164
# @bgcmaijfhdlopekn : 164
# @bgcmaijfhdlopenk : 164
# @bgcmaijfhdloepkn : 164
# @bgcmaijfhdloepnk : 164
# @bgcmaijfhdlepokn : 164
# @bgcmaijfhdleponk : 164
# @bgcmaijfhdlnpeok : 164
# @bgcmaijfhdlnopek : 164
# @bgcmaijfhdlnoepk : 164
# @bgcmaijfhdlnepok : 164
# @bgcmaijfdlhpeokn : 164
# @bgcmaijfdlhpeonk : 164
# @bgcmaijfdlhopekn : 164
# @bgcmaijfdlhopenk : 164
# @bgcmaijfdlhoepkn : 164
# @bgcmaijfdlhoepnk : 164
# @bgcmaijfdlhepokn : 164
# @bgcmaijfdlheponk : 164
# @bgcmaijfdlhnpeok : 164
# @bgcmaijfdlhnopek : 164
# @bgcmaijfdlhnoepk : 164
# @bgcmaijfdlhnepok : 164
# @bgcmaijfnldhpeok : 164
# @bgcmaijfnldhopek : 164
# @bgcmaijfnldhoepk : 164
# @bgcmaijfnldhepok : 164
# @bgcmaijfnhldpeok : 164
# @bgcmaijfnhldopek : 164
# @bgcmaijfnhldoepk : 164
# @bgcmaijfnhldepok : 164
# @bgcmaijfnhdlpeok : 164
# @bgcmaijfnhdlopek : 164
# @bgcmaijfnhdloepk : 164
# @bgcmaijfnhdlepok : 164
# @bgcmaijfndlhpeok : 164
# @bgcmaijfndlhopek : 164
# @bgcmaijfndlhoepk : 164
# @bgcmaijfndlhepok : 164
# @bgcmaiejfldhknop : 164
# @bgcmaiejfldhnkop : 164
# @bgcmaiejfkldhnop : 164
# @bgcmaiejfkhldnop : 164
# @bgcmaiejfkhdlnop : 164
# @bgcmaiejfkdlhnop : 164
# @bgcmaiejfknldhop : 164
# @bgcmaiejfknhldop : 164
# @bgcmaiejfknhdlop : 164
# @bgcmaiejfkndlhop : 164
# @bgcmaiejfhldknop : 164
# @bgcmaiejfhldnkop : 164
# @bgcmaiejfhdlknop : 164
# @bgcmaiejfhdlnkop : 164
# @bgcmaiejfdlhknop : 164
# @bgcmaiejfdlhnkop : 164
# @bgcmaiejfnldhkop : 164
# @bgcmaiejfnkldhop : 164
# @bgcmaiejfnkhldop : 164
# @bgcmaiejfnkhdlop : 164
# @bgcmaiejfnkdlhop : 164
# @bgcmaiejfnhldkop : 164
# @bgcmaiejfnhdlkop : 164
# @bgcmaiejfndlhkop : 164
# @bgcmaiefldhknjop : 164
# @bgcmaiefldhknojp : 164
# @bgcmaiefldhnkjop : 164
# @bgcmaiefldhnkojp : 164
# @bgcmaiefkldhnjop : 164
# @bgcmaiefkldhnojp : 164
# @bgcmaiefkhldnjop : 164
# @bgcmaiefkhldnojp : 164
# @bgcmaiefkhdlnjop : 164
# @bgcmaiefkhdlnojp : 164
# @bgcmaiefkdlhnjop : 164
# @bgcmaiefkdlhnojp : 164
# @bgcmaiefknldhjop : 164
# @bgcmaiefknldhojp : 164
# @bgcmaiefknhldjop : 164
# @bgcmaiefknhldojp : 164
# @bgcmaiefknhdljop : 164
# @bgcmaiefknhdlojp : 164
# @bgcmaiefkndlhjop : 164
# @bgcmaiefkndlhojp : 164
# @bgcmaiefjldhknop : 164
# @bgcmaiefjldhnkop : 164
# @bgcmaiefjkldhnop : 164
# @bgcmaiefjkhldnop : 164
# @bgcmaiefjkhdlnop : 164
# @bgcmaiefjkdlhnop : 164
# @bgcmaiefjknldhop : 164
# @bgcmaiefjknhldop : 164
# @bgcmaiefjknhdlop : 164
# @bgcmaiefjkndlhop : 164
# @bgcmaiefjhldknop : 164
# @bgcmaiefjhldnkop : 164
# @bgcmaiefjhdlknop : 164
# @bgcmaiefjhdlnkop : 164
# @bgcmaiefjdlhknop : 164
# @bgcmaiefjdlhnkop : 164
# @bgcmaiefjnldhkop : 164
# @bgcmaiefjnkldhop : 164
# @bgcmaiefjnkhldop : 164
# @bgcmaiefjnkhdlop : 164
# @bgcmaiefjnkdlhop : 164
# @bgcmaiefjnhldkop : 164
# @bgcmaiefjnhdlkop : 164
# @bgcmaiefjndlhkop : 164
# @bgcmaiefhldknjop : 164
# @bgcmaiefhldknojp : 164
# @bgcmaiefhldnkjop : 164
# @bgcmaiefhldnkojp : 164
# @bgcmaiefhdlknjop : 164
# @bgcmaiefhdlknojp : 164
# @bgcmaiefhdlnkjop : 164
# @bgcmaiefhdlnkojp : 164
# @bgcmaiefdlhknjop : 164
# @bgcmaiefdlhknojp : 164
# @bgcmaiefdlhnkjop : 164
# @bgcmaiefdlhnkojp : 164
# @bgcmaiefnldhkjop : 164
# @bgcmaiefnldhkojp : 164
# @bgcmaiefnkldhjop : 164
# @bgcmaiefnkldhojp : 164
# @bgcmaiefnkhldjop : 164
# @bgcmaiefnkhldojp : 164
# @bgcmaiefnkhdljop : 164
# @bgcmaiefnkhdlojp : 164
# @bgcmaiefnkdlhjop : 164
# @bgcmaiefnkdlhojp : 164
# @bgcmaiefnhldkjop : 164
# @bgcmaiefnhldkojp : 164
# @bgcmaiefnhdlkjop : 164
# @bgcmaiefnhdlkojp : 164
# @bgcmaiefndlhkjop : 164
# @bgcmaiefndlhkojp : 164
# @bgcmaifldhpejokn : 164
# @bgcmaifldhpejonk : 164
# @bgcmaifldhpeojkn : 164
# @bgcmaifldhpeojnk : 164
# @bgcmaifldhjpeokn : 164
# @bgcmaifldhjpeonk : 164
# @bgcmaifldhjopekn : 164
# @bgcmaifldhjopenk : 164
# @bgcmaifldhjoepkn : 164
# @bgcmaifldhjoepnk : 164
# @bgcmaifldhjepokn : 164
# @bgcmaifldhjeponk : 164
# @bgcmaifldhopejkn : 164
# @bgcmaifldhopejnk : 164
# @bgcmaifldhojpekn : 164
# @bgcmaifldhojpenk : 164
# @bgcmaifldhojepkn : 164
# @bgcmaifldhojepnk : 164
# @bgcmaifldhoepjkn : 164
# @bgcmaifldhoepjnk : 164
# @bgcmaifldhepjokn : 164
# @bgcmaifldhepjonk : 164
# @bgcmaifldhepojkn : 164
# @bgcmaifldhepojnk : 164
# @bgcmaifldhnpejok : 164
# @bgcmaifldhnpeojk : 164
# @bgcmaifldhnjpeok : 164
# @bgcmaifldhnjopek : 164
# @bgcmaifldhnjoepk : 164
# @bgcmaifldhnjepok : 164
# @bgcmaifldhnopejk : 164
# @bgcmaifldhnojpek : 164
# @bgcmaifldhnojepk : 164
# @bgcmaifldhnoepjk : 164
# @bgcmaifldhnepjok : 164
# @bgcmaifldhnepojk : 164
# @bgcmaifjldhpeokn : 164
# @bgcmaifjldhpeonk : 164
# @bgcmaifjldhopekn : 164
# @bgcmaifjldhopenk : 164
# @bgcmaifjldhoepkn : 164
# @bgcmaifjldhoepnk : 164
# @bgcmaifjldhepokn : 164
# @bgcmaifjldheponk : 164
# @bgcmaifjldhnpeok : 164
# @bgcmaifjldhnopek : 164
# @bgcmaifjldhnoepk : 164
# @bgcmaifjldhnepok : 164
# @bgcmaifjhldpeokn : 164
# @bgcmaifjhldpeonk : 164
# @bgcmaifjhldopekn : 164
# @bgcmaifjhldopenk : 164
# @bgcmaifjhldoepkn : 164
# @bgcmaifjhldoepnk : 164
# @bgcmaifjhldepokn : 164
# @bgcmaifjhldeponk : 164
# @bgcmaifjhldnpeok : 164
# @bgcmaifjhldnopek : 164
# @bgcmaifjhldnoepk : 164
# @bgcmaifjhldnepok : 164
# @bgcmaifjhdlpeokn : 164
# @bgcmaifjhdlpeonk : 164
# @bgcmaifjhdlopekn : 164
# @bgcmaifjhdlopenk : 164
# @bgcmaifjhdloepkn : 164
# @bgcmaifjhdloepnk : 164
# @bgcmaifjhdlepokn : 164
# @bgcmaifjhdleponk : 164
# @bgcmaifjhdlnpeok : 164
# @bgcmaifjhdlnopek : 164
# @bgcmaifjhdlnoepk : 164
# @bgcmaifjhdlnepok : 164
# @bgcmaifjdlhpeokn : 164
# @bgcmaifjdlhpeonk : 164
# @bgcmaifjdlhopekn : 164
# @bgcmaifjdlhopenk : 164
# @bgcmaifjdlhoepkn : 164
# @bgcmaifjdlhoepnk : 164
# @bgcmaifjdlhepokn : 164
# @bgcmaifjdlheponk : 164
# @bgcmaifjdlhnpeok : 164
# @bgcmaifjdlhnopek : 164
# @bgcmaifjdlhnoepk : 164
# @bgcmaifjdlhnepok : 164
# @bgcmaifjnldhpeok : 164
# @bgcmaifjnldhopek : 164
# @bgcmaifjnldhoepk : 164
# @bgcmaifjnldhepok : 164
# @bgcmaifjnhldpeok : 164
# @bgcmaifjnhldopek : 164
# @bgcmaifjnhldoepk : 164
# @bgcmaifjnhldepok : 164
# @bgcmaifjnhdlpeok : 164
# @bgcmaifjnhdlopek : 164
# @bgcmaifjnhdloepk : 164
# @bgcmaifjnhdlepok : 164
# @bgcmaifjndlhpeok : 164
# @bgcmaifjndlhopek : 164
# @bgcmaifjndlhoepk : 164
# @bgcmaifjndlhepok : 164
# @bgcmaifhldpejokn : 164
# @bgcmaifhldpejonk : 164
# @bgcmaifhldpeojkn : 164
# @bgcmaifhldpeojnk : 164
# @bgcmaifhldjpeokn : 164
# @bgcmaifhldjpeonk : 164
# @bgcmaifhldjopekn : 164
# @bgcmaifhldjopenk : 164
# @bgcmaifhldjoepkn : 164
# @bgcmaifhldjoepnk : 164
# @bgcmaifhldjepokn : 164
# @bgcmaifhldjeponk : 164
# @bgcmaifhldopejkn : 164
# @bgcmaifhldopejnk : 164
# @bgcmaifhldojpekn : 164
# @bgcmaifhldojpenk : 164
# @bgcmaifhldojepkn : 164
# @bgcmaifhldojepnk : 164
# @bgcmaifhldoepjkn : 164
# @bgcmaifhldoepjnk : 164
# @bgcmaifhldepjokn : 164
# @bgcmaifhldepjonk : 164
# @bgcmaifhldepojkn : 164
# @bgcmaifhldepojnk : 164
# @bgcmaifhldnpejok : 164
# @bgcmaifhldnpeojk : 164
# @bgcmaifhldnjpeok : 164
# @bgcmaifhldnjopek : 164
# @bgcmaifhldnjoepk : 164
# @bgcmaifhldnjepok : 164
# @bgcmaifhldnopejk : 164
# @bgcmaifhldnojpek : 164
# @bgcmaifhldnojepk : 164
# @bgcmaifhldnoepjk : 164
# @bgcmaifhldnepjok : 164
# @bgcmaifhldnepojk : 164
# @bgcmaifhdlpejokn : 164
# @bgcmaifhdlpejonk : 164
# @bgcmaifhdlpeojkn : 164
# @bgcmaifhdlpeojnk : 164
# @bgcmaifhdljpeokn : 164
# @bgcmaifhdljpeonk : 164
# @bgcmaifhdljopekn : 164
# @bgcmaifhdljopenk : 164
# @bgcmaifhdljoepkn : 164
# @bgcmaifhdljoepnk : 164
# @bgcmaifhdljepokn : 164
# @bgcmaifhdljeponk : 164
# @bgcmaifhdlopejkn : 164
# @bgcmaifhdlopejnk : 164
# @bgcmaifhdlojpekn : 164
# @bgcmaifhdlojpenk : 164
# @bgcmaifhdlojepkn : 164
# @bgcmaifhdlojepnk : 164
# @bgcmaifhdloepjkn : 164
# @bgcmaifhdloepjnk : 164
# @bgcmaifhdlepjokn : 164
# @bgcmaifhdlepjonk : 164
# @bgcmaifhdlepojkn : 164
# @bgcmaifhdlepojnk : 164
# @bgcmaifhdlnpejok : 164
# @bgcmaifhdlnpeojk : 164
# @bgcmaifhdlnjpeok : 164
# @bgcmaifhdlnjopek : 164
# @bgcmaifhdlnjoepk : 164
# @bgcmaifhdlnjepok : 164
# @bgcmaifhdlnopejk : 164
# @bgcmaifhdlnojpek : 164
# @bgcmaifhdlnojepk : 164
# @bgcmaifhdlnoepjk : 164
# @bgcmaifhdlnepjok : 164
# @bgcmaifhdlnepojk : 164
# @bgcmaifdlhpejokn : 164
# @bgcmaifdlhpejonk : 164
# @bgcmaifdlhpeojkn : 164
# @bgcmaifdlhpeojnk : 164
# @bgcmaifdlhjpeokn : 164
# @bgcmaifdlhjpeonk : 164
# @bgcmaifdlhjopekn : 164
# @bgcmaifdlhjopenk : 164
# @bgcmaifdlhjoepkn : 164
# @bgcmaifdlhjoepnk : 164
# @bgcmaifdlhjepokn : 164
# @bgcmaifdlhjeponk : 164
# @bgcmaifdlhopejkn : 164
# @bgcmaifdlhopejnk : 164
# @bgcmaifdlhojpekn : 164
# @bgcmaifdlhojpenk : 164
# @bgcmaifdlhojepkn : 164
# @bgcmaifdlhojepnk : 164
# @bgcmaifdlhoepjkn : 164
# @bgcmaifdlhoepjnk : 164
# @bgcmaifdlhepjokn : 164
# @bgcmaifdlhepjonk : 164
# @bgcmaifdlhepojkn : 164
# @bgcmaifdlhepojnk : 164
# @bgcmaifdlhnpejok : 164
# @bgcmaifdlhnpeojk : 164
# @bgcmaifdlhnjpeok : 164
# @bgcmaifdlhnjopek : 164
# @bgcmaifdlhnjoepk : 164
# @bgcmaifdlhnjepok : 164
# @bgcmaifdlhnopejk : 164
# @bgcmaifdlhnojpek : 164
# @bgcmaifdlhnojepk : 164
# @bgcmaifdlhnoepjk : 164
# @bgcmaifdlhnepjok : 164
# @bgcmaifdlhnepojk : 164
# @bgcmaifnldhpejok : 164
# @bgcmaifnldhpeojk : 164
# @bgcmaifnldhjpeok : 164
# @bgcmaifnldhjopek : 164
# @bgcmaifnldhjoepk : 164
# @bgcmaifnldhjepok : 164
# @bgcmaifnldhopejk : 164
# @bgcmaifnldhojpek : 164
# @bgcmaifnldhojepk : 164
# @bgcmaifnldhoepjk : 164
# @bgcmaifnldhepjok : 164
# @bgcmaifnldhepojk : 164
# @bgcmaifnhldpejok : 164
# @bgcmaifnhldpeojk : 164
# @bgcmaifnhldjpeok : 164
# @bgcmaifnhldjopek : 164
# @bgcmaifnhldjoepk : 164
# @bgcmaifnhldjepok : 164
# @bgcmaifnhldopejk : 164
# @bgcmaifnhldojpek : 164
# @bgcmaifnhldojepk : 164
# @bgcmaifnhldoepjk : 164
# @bgcmaifnhldepjok : 164
# @bgcmaifnhldepojk : 164
# @bgcmaifnhdlpejok : 164
# @bgcmaifnhdlpeojk : 164
# @bgcmaifnhdljpeok : 164
# @bgcmaifnhdljopek : 164
# @bgcmaifnhdljoepk : 164
# @bgcmaifnhdljepok : 164
# @bgcmaifnhdlopejk : 164
# @bgcmaifnhdlojpek : 164
# @bgcmaifnhdlojepk : 164
# @bgcmaifnhdloepjk : 164
# @bgcmaifnhdlepjok : 164
# @bgcmaifnhdlepojk : 164
# @bgcmaifndlhpejok : 164
# @bgcmaifndlhpeojk : 164
# @bgcmaifndlhjpeok : 164
# @bgcmaifndlhjopek : 164
# @bgcmaifndlhjoepk : 164
# @bgcmaifndlhjepok : 164
# @bgcmaifndlhopejk : 164
# @bgcmaifndlhojpek : 164
# @bgcmaifndlhojepk : 164
# @bgcmaifndlhoepjk : 164
# @bgcmaifndlhepjok : 164
# @bgcmaifndlhepojk : 164
# @bgcmajiefldhknop : 164
# @bgcmajiefldhnkop : 164
# @bgcmajiefkldhnop : 164
# @bgcmajiefkhldnop : 164
# @bgcmajiefkhdlnop : 164
# @bgcmajiefkdlhnop : 164
# @bgcmajiefknldhop : 164
# @bgcmajiefknhldop : 164
# @bgcmajiefknhdlop : 164
# @bgcmajiefkndlhop : 164
# @bgcmajiefhldknop : 164
# @bgcmajiefhldnkop : 164
# @bgcmajiefhdlknop : 164
# @bgcmajiefhdlnkop : 164
# @bgcmajiefdlhknop : 164
# @bgcmajiefdlhnkop : 164
# @bgcmajiefnldhkop : 164
# @bgcmajiefnkldhop : 164
# @bgcmajiefnkhldop : 164
# @bgcmajiefnkhdlop : 164
# @bgcmajiefnkdlhop : 164
# @bgcmajiefnhldkop : 164
# @bgcmajiefnhdlkop : 164
# @bgcmajiefndlhkop : 164
# @bgcmajifldhpeokn : 164
# @bgcmajifldhpeonk : 164
# @bgcmajifldhopekn : 164
# @bgcmajifldhopenk : 164
# @bgcmajifldhoepkn : 164
# @bgcmajifldhoepnk : 164
# @bgcmajifldhepokn : 164
# @bgcmajifldheponk : 164
# @bgcmajifldhnpeok : 164
# @bgcmajifldhnopek : 164
# @bgcmajifldhnoepk : 164
# @bgcmajifldhnepok : 164
# @bgcmajifhldpeokn : 164
# @bgcmajifhldpeonk : 164
# @bgcmajifhldopekn : 164
# @bgcmajifhldopenk : 164
# @bgcmajifhldoepkn : 164
# @bgcmajifhldoepnk : 164
# @bgcmajifhldepokn : 164
# @bgcmajifhldeponk : 164
# @bgcmajifhldnpeok : 164
# @bgcmajifhldnopek : 164
# @bgcmajifhldnoepk : 164
# @bgcmajifhldnepok : 164
# @bgcmajifhdlpeokn : 164
# @bgcmajifhdlpeonk : 164
# @bgcmajifhdlopekn : 164
# @bgcmajifhdlopenk : 164
# @bgcmajifhdloepkn : 164
# @bgcmajifhdloepnk : 164
# @bgcmajifhdlepokn : 164
# @bgcmajifhdleponk : 164
# @bgcmajifhdlnpeok : 164
# @bgcmajifhdlnopek : 164
# @bgcmajifhdlnoepk : 164
# @bgcmajifhdlnepok : 164
# @bgcmajifdlhpeokn : 164
# @bgcmajifdlhpeonk : 164
# @bgcmajifdlhopekn : 164
# @bgcmajifdlhopenk : 164
# @bgcmajifdlhoepkn : 164
# @bgcmajifdlhoepnk : 164
# @bgcmajifdlhepokn : 164
# @bgcmajifdlheponk : 164
# @bgcmajifdlhnpeok : 164
# @bgcmajifdlhnopek : 164
# @bgcmajifdlhnoepk : 164
# @bgcmajifdlhnepok : 164
# @bgcmajifnldhpeok : 164
# @bgcmajifnldhopek : 164
# @bgcmajifnldhoepk : 164
# @bgcmajifnldhepok : 164
# @bgcmajifnhldpeok : 164
# @bgcmajifnhldopek : 164
# @bgcmajifnhldoepk : 164
# @bgcmajifnhldepok : 164
# @bgcmajifnhdlpeok : 164
# @bgcmajifnhdlopek : 164
# @bgcmajifnhdloepk : 164
# @bgcmajifnhdlepok : 164
# @bgcmajifndlhpeok : 164
# @bgcmajifndlhopek : 164
# @bgcmajifndlhoepk : 164
# @bgcmajifndlhepok : 164
# @bgcmajhdpeioflkn : 164
# @bgcmajhdpeioflnk : 164
# @bgcmajhdpeiofkln : 164
# @bgcmajhdpeiofknl : 162
# @bgcmajhdpeiofnkl : 162
# @bgcmajhdpeifoknl : 162
# @bgcmajhdpeifonkl : 162
# @bgcmajhdipeofknl : 162
# @bgcmajhdipeofnkl : 162
# @bgcmajhdipefoknl : 162
# @bgcmajhdipefonkl : 162
# @bgcmajhdiepofknl : 162
# @bgcmajhdiepofnkl : 162
# @bgcmajhdiepfoknl : 162
# @bgcmajhdiepfonkl : 162
# @bgcmajhdofpeiknl : 162
# @bgcmajhdofpeinkl : 162
# @bgcmajhdofipeknl : 162
# @bgcmajhdofipenkl : 162
# @bgcmajhdofiepknl : 162
# @bgcmajhdofiepnkl : 162
# @bgcmajhdofepiknl : 162
# @bgcmajhdofepinkl : 162
# @bgcmajhdepiofknl : 162
# @bgcmajhdepiofnkl : 162
# @bgcmajhdepifoknl : 162
# @bgcmajhdepifonkl : 162
# @bgcmajhdfopeiknl : 162
# @bgcmajhdfopeinkl : 162
# @bgcmajhdfoipeknl : 162
# @bgcmajhdfoipenkl : 162
# @bgcmajhdfoiepknl : 162
# @bgcmajhdfoiepnkl : 162
# @bgcmajhdfoepiknl : 162
# @bgcmajhdfoepinkl : 162
# @bgcmajhdnpeiofkl : 162
# @bgcmajhdnpeifokl : 162
# @bgcmajhdnipeofkl : 162
# @bgcmajhdnipefokl : 162
# @bgcmajhdniepofkl : 162
# @bgcmajhdniepfokl : 162
# @bgcmajhdnofpeikl : 162
# @bgcmajhdnofipekl : 162
# @bgcmajhdnofiepkl : 162
# @bgcmajhdnofepikl : 162
# @bgcmajhdnepiofkl : 162
# @bgcmajhdnepifokl : 162
# @bgcmajhdnfopeikl : 162
# @bgcmajhdnfoipekl : 162
# @bgcmajhdnfoiepkl : 162
# @bgcmajhdnfoepikl : 162
# @bgcmajdhpeiofknl : 162
# @bgcmajdhpeiofnkl : 162
# @bgcmajdhpeifoknl : 162
# @bgcmajdhpeifonkl : 162
# @bgcmajdhipeofknl : 162
# @bgcmajdhipeofnkl : 162
# @bgcmajdhipefoknl : 162
# @bgcmajdhipefonkl : 162
# @bgcmajdhiepofknl : 162
# @bgcmajdhiepofnkl : 162
# @bgcmajdhiepfoknl : 162
# @bgcmajdhiepfonkl : 162
# @bgcmajdhofpeiknl : 162
# @bgcmajdhofpeinkl : 162
# @bgcmajdhofipeknl : 162
# @bgcmajdhofipenkl : 162
# @bgcmajdhofiepknl : 162
# @bgcmajdhofiepnkl : 162
# @bgcmajdhofepiknl : 162
# @bgcmajdhofepinkl : 162
# @bgcmajdhepiofknl : 162
# @bgcmajdhepiofnkl : 162
# @bgcmajdhepifoknl : 162
# @bgcmajdhepifonkl : 162
# @bgcmajdhfopeiknl : 162
# @bgcmajdhfopeinkl : 162
# @bgcmajdhfoipeknl : 162
# @bgcmajdhfoipenkl : 162
# @bgcmajdhfoiepknl : 162
# @bgcmajdhfoiepnkl : 162
# @bgcmajdhfoepiknl : 162
# @bgcmajdhfoepinkl : 162
# @bgcmajdhnpeiofkl : 162
# @bgcmajdhnpeifokl : 162
# @bgcmajdhnipeofkl : 162
# @bgcmajdhnipefokl : 162
# @bgcmajdhniepofkl : 162
# @bgcmajdhniepfokl : 162
# @bgcmajdhnofpeikl : 162
# @bgcmajdhnofipekl : 162
# @bgcmajdhnofiepkl : 162
# @bgcmajdhnofepikl : 162
# @bgcmajdhnepiofkl : 162
# @bgcmajdhnepifokl : 162
# @bgcmajdhnfopeikl : 162
# @bgcmajdhnfoipekl : 162
# @bgcmajdhnfoiepkl : 162
# @bgcmajdhnfoepikl : 162
# @bgcmajfldhpeikno : 162
# @bgcmajfldhpeiokn : 160
# @bgcmajfldhpeionk : 160
# @bgcmajfldhipeokn : 160
# @bgcmajfldhipeonk : 160
# @bgcmajfldhiepokn : 160
# @bgcmajfldhieponk : 160
# @bgcmajfldhopeikn : 160
# @bgcmajfldhopeink : 160
# @bgcmajfldhoipekn : 160
# @bgcmajfldhoipenk : 160
# @bgcmajfldhoiepkn : 160
# @bgcmajfldhoiepnk : 160
# @bgcmajfldhoepikn : 160
# @bgcmajfldhoepink : 160
# @bgcmajfldhepiokn : 160
# @bgcmajfldhepionk : 160
# @bgcmajfldhnpeiok : 160
# @bgcmajfldhnipeok : 160
# @bgcmajfldhniepok : 160
# @bgcmajfldhnopeik : 160
# @bgcmajfldhnoipek : 160
# @bgcmajfldhnoiepk : 160
# @bgcmajfldhnoepik : 160
# @bgcmajfldhnepiok : 160
# @bgcmajfhldpeiokn : 160
# @bgcmajfhldpeionk : 160
# @bgcmajfhldipeokn : 160
# @bgcmajfhldipeonk : 160
# @bgcmajfhldiepokn : 160
# @bgcmajfhldieponk : 160
# @bgcmajfhldopeikn : 160
# @bgcmajfhldopeink : 160
# @bgcmajfhldoipekn : 160
# @bgcmajfhldoipenk : 160
# @bgcmajfhldoiepkn : 160
# @bgcmajfhldoiepnk : 160
# @bgcmajfhldoepikn : 160
# @bgcmajfhldoepink : 160
# @bgcmajfhldepiokn : 160
# @bgcmajfhldepionk : 160
# @bgcmajfhldnpeiok : 160
# @bgcmajfhldnipeok : 160
# @bgcmajfhldniepok : 160
# @bgcmajfhldnopeik : 160
# @bgcmajfhldnoipek : 160
# @bgcmajfhldnoiepk : 160
# @bgcmajfhldnoepik : 160
# @bgcmajfhldnepiok : 160
# @bgcmajfhdlpeiokn : 160
# @bgcmajfhdlpeionk : 160
# @bgcmajfhdlipeokn : 160
# @bgcmajfhdlipeonk : 160
# @bgcmajfhdliepokn : 160
# @bgcmajfhdlieponk : 160
# @bgcmajfhdlopeikn : 160
# @bgcmajfhdlopeink : 160
# @bgcmajfhdloipekn : 160
# @bgcmajfhdloipenk : 160
# @bgcmajfhdloiepkn : 160
# @bgcmajfhdloiepnk : 160
# @bgcmajfhdloepikn : 160
# @bgcmajfhdloepink : 160
# @bgcmajfhdlepiokn : 160
# @bgcmajfhdlepionk : 160
# @bgcmajfhdlnpeiok : 160
# @bgcmajfhdlnipeok : 160
# @bgcmajfhdlniepok : 160
# @bgcmajfhdlnopeik : 160
# @bgcmajfhdlnoipek : 160
# @bgcmajfhdlnoiepk : 160
# @bgcmajfhdlnoepik : 160
# @bgcmajfhdlnepiok : 160
# @bgcmajfdlhpeiokn : 160
# @bgcmajfdlhpeionk : 160
# @bgcmajfdlhipeokn : 160
# @bgcmajfdlhipeonk : 160
# @bgcmajfdlhiepokn : 160
# @bgcmajfdlhieponk : 160
# @bgcmajfdlhopeikn : 160
# @bgcmajfdlhopeink : 160
# @bgcmajfdlhoipekn : 160
# @bgcmajfdlhoipenk : 160
# @bgcmajfdlhoiepkn : 160
# @bgcmajfdlhoiepnk : 160
# @bgcmajfdlhoepikn : 160
# @bgcmajfdlhoepink : 160
# @bgcmajfdlhepiokn : 160
# @bgcmajfdlhepionk : 160
# @bgcmajfdlhnpeiok : 160
# @bgcmajfdlhnipeok : 160
# @bgcmajfdlhniepok : 160
# @bgcmajfdlhnopeik : 160
# @bgcmajfdlhnoipek : 160
# @bgcmajfdlhnoiepk : 160
# @bgcmajfdlhnoepik : 160
# @bgcmajfdlhnepiok : 160
# @bgcmajfnldhpeiok : 160
# @bgcmajfnldhipeok : 160
# @bgcmajfnldhiepok : 160
# @bgcmajfnldhopeik : 160
# @bgcmajfnldhoipek : 160
# @bgcmajfnldhoiepk : 160
# @bgcmajfnldhoepik : 160
# @bgcmajfnldhepiok : 160
# @bgcmajfnhldpeiok : 160
# @bgcmajfnhldipeok : 160
# @bgcmajfnhldiepok : 160
# @bgcmajfnhldopeik : 160
# @bgcmajfnhldoipek : 160
# @bgcmajfnhldoiepk : 160
# @bgcmajfnhldoepik : 160
# @bgcmajfnhldepiok : 160
# @bgcmajfnhdlpeiok : 160
# @bgcmajfnhdlipeok : 160
# @bgcmajfnhdliepok : 160
# @bgcmajfnhdlopeik : 160
# @bgcmajfnhdloipek : 160
# @bgcmajfnhdloiepk : 160
# @bgcmajfnhdloepik : 160
# @bgcmajfnhdlepiok : 160
# @bgcmajfndlhpeiok : 160
# @bgcmajfndlhipeok : 160
# @bgcmajfndlhiepok : 160
# @bgcmajfndlhopeik : 160
# @bgcmajfndlhoipek : 160
# @bgcmajfndlhoiepk : 160
# @bgcmajfndlhoepik : 160
# @bgcmajfndlhepiok : 160
# @bgcmahdpeijoflkn : 160
# @bgcmahdpeijoflnk : 160
# @bgcmahdpeijofkln : 160
# @bgcmahdpeijofknl : 158
# @bgcmahdpeijofnkl : 158
# @bgcmahdpeijfoknl : 158
# @bgcmahdpeijfonkl : 158
# @bgcmahdpeiofjknl : 158
# @bgcmahdpeiofjnkl : 158
# @bgcmahdpeifojknl : 158
# @bgcmahdpeifojnkl : 158
# @bgcmahdipejofknl : 158
# @bgcmahdipejofnkl : 158
# @bgcmahdipejfoknl : 158
# @bgcmahdipejfonkl : 158
# @bgcmahdipeofjknl : 158
# @bgcmahdipeofjnkl : 158
# @bgcmahdipefojknl : 158
# @bgcmahdipefojnkl : 158
# @bgcmahdiepjofknl : 158
# @bgcmahdiepjofnkl : 158
# @bgcmahdiepjfoknl : 158
# @bgcmahdiepjfonkl : 158
# @bgcmahdiepofjknl : 158
# @bgcmahdiepofjnkl : 158
# @bgcmahdiepfojknl : 158
# @bgcmahdiepfojnkl : 158
# @bgcmahdjpeiofknl : 158
# @bgcmahdjpeiofnkl : 158
# @bgcmahdjpeifoknl : 158
# @bgcmahdjpeifonkl : 158
# @bgcmahdjipeofknl : 158
# @bgcmahdjipeofnkl : 158
# @bgcmahdjipefoknl : 158
# @bgcmahdjipefonkl : 158
# @bgcmahdjiepofknl : 158
# @bgcmahdjiepofnkl : 158
# @bgcmahdjiepfoknl : 158
# @bgcmahdjiepfonkl : 158
# @bgcmahdjofpeiknl : 158
# @bgcmahdjofpeinkl : 158
# @bgcmahdjofipeknl : 158
# @bgcmahdjofipenkl : 158
# @bgcmahdjofiepknl : 158
# @bgcmahdjofiepnkl : 158
# @bgcmahdjofepiknl : 158
# @bgcmahdjofepinkl : 158
# @bgcmahdjepiofknl : 158
# @bgcmahdjepiofnkl : 158
# @bgcmahdjepifoknl : 158
# @bgcmahdjepifonkl : 158
# @bgcmahdjfopeiknl : 158
# @bgcmahdjfopeinkl : 158
# @bgcmahdjfoipeknl : 158
# @bgcmahdjfoipenkl : 158
# @bgcmahdjfoiepknl : 158
# @bgcmahdjfoiepnkl : 158
# @bgcmahdjfoepiknl : 158
# @bgcmahdjfoepinkl : 158
# @bgcmahdofpeijknl : 158
# @bgcmahdofpeijnkl : 158
# @bgcmahdofipejknl : 158
# @bgcmahdofipejnkl : 158
# @bgcmahdofiepjknl : 158
# @bgcmahdofiepjnkl : 158
# @bgcmahdofjpeiknl : 158
# @bgcmahdofjpeinkl : 158
# @bgcmahdofjipeknl : 158
# @bgcmahdofjipenkl : 158
# @bgcmahdofjiepknl : 158
# @bgcmahdofjiepnkl : 158
# @bgcmahdofjepiknl : 158
# @bgcmahdofjepinkl : 158
# @bgcmahdofepijknl : 158
# @bgcmahdofepijnkl : 158
# @bgcmahdepijofknl : 158
# @bgcmahdepijofnkl : 158
# @bgcmahdepijfoknl : 158
# @bgcmahdepijfonkl : 158
# @bgcmahdepiofjknl : 158
# @bgcmahdepiofjnkl : 158
# @bgcmahdepifojknl : 158
# @bgcmahdepifojnkl : 158
# @bgcmahdfopeijknl : 158
# @bgcmahdfopeijnkl : 158
# @bgcmahdfoipejknl : 158
# @bgcmahdfoipejnkl : 158
# @bgcmahdfoiepjknl : 158
# @bgcmahdfoiepjnkl : 158
# @bgcmahdfojpeiknl : 158
# @bgcmahdfojpeinkl : 158
# @bgcmahdfojipeknl : 158
# @bgcmahdfojipenkl : 158
# @bgcmahdfojiepknl : 158
# @bgcmahdfojiepnkl : 158
# @bgcmahdfojepiknl : 158
# @bgcmahdfojepinkl : 158
# @bgcmahdfoepijknl : 158
# @bgcmahdfoepijnkl : 158
# @bgcmahdnpeijofkl : 158
# @bgcmahdnpeijfokl : 158
# @bgcmahdnpeiofjkl : 158
# @bgcmahdnpeifojkl : 158
# @bgcmahdnipejofkl : 158
# @bgcmahdnipejfokl : 158
# @bgcmahdnipeofjkl : 158
# @bgcmahdnipefojkl : 158
# @bgcmahdniepjofkl : 158
# @bgcmahdniepjfokl : 158
# @bgcmahdniepofjkl : 158
# @bgcmahdniepfojkl : 158
# @bgcmahdnjpeiofkl : 158
# @bgcmahdnjpeifokl : 158
# @bgcmahdnjipeofkl : 158
# @bgcmahdnjipefokl : 158
# @bgcmahdnjiepofkl : 158
# @bgcmahdnjiepfokl : 158
# @bgcmahdnjofpeikl : 158
# @bgcmahdnjofipekl : 158
# @bgcmahdnjofiepkl : 158
# @bgcmahdnjofepikl : 158
# @bgcmahdnjepiofkl : 158
# @bgcmahdnjepifokl : 158
# @bgcmahdnjfopeikl : 158
# @bgcmahdnjfoipekl : 158
# @bgcmahdnjfoiepkl : 158
# @bgcmahdnjfoepikl : 158
# @bgcmahdnofpeijkl : 158
# @bgcmahdnofipejkl : 158
# @bgcmahdnofiepjkl : 158
# @bgcmahdnofjpeikl : 158
# @bgcmahdnofjipekl : 158
# @bgcmahdnofjiepkl : 158
# @bgcmahdnofjepikl : 158
# @bgcmahdnofepijkl : 158
# @bgcmahdnepijofkl : 158
# @bgcmahdnepijfokl : 158
# @bgcmahdnepiofjkl : 158
# @bgcmahdnepifojkl : 158
# @bgcmahdnfopeijkl : 158
# @bgcmahdnfoipejkl : 158
# @bgcmahdnfoiepjkl : 158
# @bgcmahdnfojpeikl : 158
# @bgcmahdnfojipekl : 158
# @bgcmahdnfojiepkl : 158
# @bgcmahdnfojepikl : 158
# @bgcmahdnfoepijkl : 158
# InterruptException:
#
# Stacktrace:
#  [1] indexed_iterate(::Pair{Char,Tuple{Int64,Array{Char,1}}}, ::Int64, ::Int64) at ./pair.jl:50
#  [2] part1(::String) at ./In[47]:18
#  [3] top-level scope at In[49]:3

# %%
arr = floodfill(m, CartesianIndex(18, 2))
# Out:
# 24×5 Array{Int64,2}:
#  -1  -1  -1  -1  -1
#  -1  16  -1  28  -1
#  -1  15  -1  27  -1
#  -1  14  -1  26  -1
#  -1  13  -1  25  -1
#  -1  12  -1  24  -1
#  -1  11  -1  23  -1
#  -1  10  -1  22  -1
#  -1   9  -1  21  -1
#  -1   8  -1  20  -1
#  -1   7  -1  19  -1
#  -1   6  -1  18  -1
#  -1   5  -1  17  -1
#  -1   4  -1  16  -1
#  -1   3  -1  15  -1
#  -1   2  -1  14  -1
#  -1   1  -1  13  -1
#  -1   0  -1  12  -1
#  -1   1  -1  11  -1
#  -1   2  -1  10  -1
#  -1   3  -1   9  -1
#  -1   4  -1   8  -1
#  -1   5   6   7  -1
#  -1  -1  -1  -1  -1

# %%
get_door_keys(m, arr, CartesianIndex(2, 2), CartesianIndex(18, 2))
# Out:
# CartesianIndex(2, 2)CartesianIndex(18, 2)
# 16
# 0
# 4-element Array{Char,1}:
#  'd'
#  'e'
#  'c'
#  'a'

# %%
res = build_info(m)
keys(res['@'])
# Out:
# Base.KeySet for a Dict{Char,Tuple{Int64,Array{Char,1}}} with 6 entries. Keys:
#   'f'
#   'a'
#   'c'
#   'd'
#   'e'
#   'b'

# %%
intersect(res['@']['f'][2], ['a', 'c', 'x'])
# Out:
# 2-element Array{Char,1}:
#  'c'
#  'a'

# %%
struct Maze
    m::Array{Char, 2}
    score::Int
end

Maze(s::Vector{T}, score::Int) where T <: String = Maze(hcat(collect.(s)...), score)
Maze(s::Vector{T}) where T <: String = Maze(s, 0)

h(m::Maze, l1, l2) = sum(abs.(Tuple(l1 - l2)))

val(m::Maze, l) = m.m[l]

allowed(m::Maze) = [collect('a':'z'); '@'; '.']

upper(c::Char) = c + 'A' - 'a'

function neighbours(m::Maze, l)
    dirs = CartesianIndex.([(0, 1), (1, 0), (0, -1), (-1, 0)])
    [l + d for d in dirs[[val(m, l + d) in allowed(m) for d in dirs]]]
end

function neighbours2(m::Maze, l)
    dirs = CartesianIndex.([(0, 1), (1, 0), (0, -1), (-1, 0)])
    [l + d for d in dirs[[val(m, l + d) != '#' for d in dirs]]]
end

function reconstruct_path(came_from::Dict{T, T}, current::T) where T
    path = T[]
    prev = current
    while current in keys(came_from)
        push!(path, current)
        current = came_from[current]
        prev = current
    end
    
    reverse(path)
end

function least(openset, scores)
    m = -1
    res = nothing
    for node in openset
        if m < 0 || scores[node][2] < m
            m = scores[node][2]
            res = node
        end
    end
    
    res
end

function astar(m::U, start::T, goal::T) where {T, U}
    openset = Set([start])
    scores = Dict(start => [0, h(m, start, goal)])
    came_from = Dict{T, T}()
    current = start
    while !isempty(openset)
        current = least(openset, scores)
        if current == goal
            return reconstruct_path(came_from, goal)
        end
        
        delete!(openset, current)
        for neighbour in neighbours(m, current)
            tentative_g_score = scores[current][1] + 1
            neighbour_g_score = get!(scores, neighbour, [-1, h(m, neighbour, goal)])[1]
            if neighbour_g_score < 0 || neighbour_g_score > tentative_g_score
                came_from[neighbour] = current
                scores[neighbour][1] = tentative_g_score
                if !(neighbour in openset) push!(openset, neighbour) end
            end
        end
    end
                
    if current != goal return T[] end
end

heur(hdict, c, ks) = sum([v for (k, v) in hdict[c] if k in ks])

# %%
function floodfill(m::Maze)
    arr = fill(-1, size(m.m)...)
    start = hero(m)
    arr[start] = 0
    acc = [start]
    while !isempty(acc)
        loc = popfirst!(acc)
        for n in neighbours(m, loc)
            if arr[n] == -1 || arr[n] > arr[loc] + 1
                arr[n] = arr[loc] + 1
                push!(acc, n)
            end
        end
    end
    
    arr
end

function floodfill2(m::Maze, start)
    arr = fill(-1, size(m.m)...)
    arr[start] = 0
    acc = [start]
    while !isempty(acc)
        loc = popfirst!(acc)
        for n in neighbours2(m, loc)
            if arr[n] == -1 || arr[n] > arr[loc] + 1
                arr[n] = arr[loc] + 1
                push!(acc, n)
            end
        end
    end
    
    arr
end

function build_proto(m::Maze)
    res = Dict()
    for (k, loc) in mkeys(m)
        arr = floodfill2(m, loc)
        res[k] = Dict([(k1, arr[v1]) for (k1, v1) in mkeys(m)])
    end
    
    arr = floodfill2(m, hero(m))
    res['@'] = Dict([(k1, arr[v1]) for (k1, v1) in mkeys(m)])
    
    res
end

function least(openset, scores)
    m = -1
    res = nothing
    for node in openset
        if m < 0 || scores[node][2] < m
            m = scores[node][2]
            res = node
        end
    end
    
    res
end

function least2(openset, scores)
    m = -1
    res = nothing
    for node in openset
        if m < 0 || scores[node[2]] < m
            m = scores[node[2]]
            res = node
        end
    end
end

function xstar(m, start = "@")
    hdict = build_proto(m)
    openset = Set([(m, start)])
    scores = Dict(start => heur(hdict, start[end], keys(mkeys(m))))
    came_from = Dict()
    current = start
    while !isempty(openset)
        current = least2(openset, scores)
        current_maze, current_path, current_key = current
        
        if isempty(mkeys(current_maze))
             return (came_from, current_path, current_key)
        end
        
        delete!(openset, current)
        
        paths = floodfill(current_maze)
        available_keys = filter(x -> x[2] > 0, [(k, paths[v]) for (k, v) in mkeys(current_maze)])
        
        for (k, l) in available_keys
            new_m = copy(current_maze.m)
            new_m[hero(current_maze)] = '.'
            new_m[mkeys(current_maze)[k]] = '@'
            if uppercase(k) in keys(doors(current_maze)) new_m[doors(current_maze)[uppercase(k)]] = '.' end
            push!(openset, (Maze(new_m, state.score + l), current_path * k))
        end
        
        for (k, l) in available_keys
            tentative_g_score = scores[(current_path, current_key)][1] + l
            neighbour_g_score = get!(scores, (current_path*string(k), ))
        end
        
        for neighbour in neighbours(m, current)
            tentative_g_score = scores[current][1] + 1
            neighbour_g_score = get!(scores, neighbour, [-1, h(m, neighbour, goal)])[1]
            if neighbour_g_score < 0 || neighbour_g_score > tentative_g_score
                came_from[neighbour] = current
                scores[neighbour][1] = tentative_g_score
                if !(neighbour in openset) push!(openset, neighbour) end
            end
        end
    end
                
    if current != goal return T[] end
end

# %%
find_element(m::Maze, el::Char) = get(CartesianIndices(m.m)[m.m .== el], 1, nothing)
find_elements(m::Maze, els) = [(x, find_element(m, x)) for x in els if find_element(m, x) != nothing]
mkeys(m::Maze) = Dict(find_elements(m, 'a':'z'))
doors(m::Maze) = Dict(find_elements(m, 'A':'Z'))
hero(m::Maze) = find_element(m, '@')

# %%
m = Maze(readlines("input.txt"))
sum(values(build_proto(m)['u']))

# %%
arr = floodfill(m)

# %%
filter(x -> x[2] > 0, [(k, arr[v]) for (k, v) in mkeys(m)])
# [(k, arr[v]) for (k, v) in mkeys(m)]

# %%
## A-star???

function part1(inp = "input.txt")
    m = Maze(readlines(inp))
    v1 = []
    acc = [(m, "")]
    min_score = -1
    while !isempty(acc)
        state, path = pop!(acc)
        println(join(path), " : ", state.score, " : ", min_score, " : ", length(v1))
        paths = floodfill(state)
        available_keys = filter(x -> x[2] > 0, [(k, paths[v]) for (k, v) in mkeys(state)])
        if isempty(available_keys)
            if isempty(mkeys(state))
                if min_score < 0 || state.score < min_score 
                    min_score = state.score 
                    push!(v1, (path, state.score))
                    continue
                end
            end
        end
        for (k, l) in available_keys
            if min_score > 0 && (state.score + l) > min_score continue end
            new_m = copy(state.m)
            new_m[hero(state)] = '.'
            new_m[mkeys(state)[k]] = '@'
            if uppercase(k) in keys(doors(state)) new_m[doors(state)[uppercase(k)]] = '.' end
            push!(acc, (Maze(new_m, state.score + l), path * k))
        end
    end
    
    v1
end

# %%
h1(m::Maze, loc) = sum([sum(abs.(Tuple(loc - v))) for (k, v) in mkeys(m)])

# %%
function part1(inp = "input.txt")
    m = Maze(readlines(inp))
    v1 = []
    acc = [(m, "")]
    min_score = -1
    while !isempty(acc)
        state, path = pop!(acc)
        println(join(path), " : ", state.score, " : ", min_score, " : ", length(v1))
        paths = floodfill(state)
        available_keys = filter(x -> x[2] > 0, [(k, paths[v]) for (k, v) in mkeys(state)])
        if isempty(available_keys)
            if isempty(mkeys(state))
                if min_score < 0 || state.score < min_score 
                    min_score = state.score 
                    push!(v1, (path, state.score))
                    continue
                end
            end
        end
        for (k, l) in available_keys
            if min_score > 0 && (state.score + l) > min_score continue end
            new_m = copy(state.m)
            new_m[hero(state)] = '.'
            new_m[mkeys(state)[k]] = '@'
            if uppercase(k) in keys(doors(state)) new_m[doors(state)[uppercase(k)]] = '.' end
            push!(acc, (Maze(new_m, state.score + l), path * k))
        end
    end
    
    v1
end

# %%
res = part1("test2.txt")

# %%
m = Maze(readlines("input.txt"))
hdict = build_proto(m)
heur(hdict, 'a', keys(mkeys(m)))
# 5806
# sum(values(build_proto(m)['@']))

# %%
h1(m, hero(m))

# %%
function f1(m)
#     mkeys(m)
#     hero(m)
    astar(m, hero(m), mkeys(m)['a'])
    # available_keys = filter( x -> x[2] > 0, [(k, length(astar(m, hero(m), loc))) for (k, loc) in mkeys(m)])
end

# %%
using BenchmarkTools

@benchmark f1($m)

# %%
mkeys(m)

# %%
Profile.print()

# %%
Profile.print(format=:flat)

# %%
x0 = hero(m)
x1 = neighbours(m, hero(m))[4]
astar(m, x0, x1)

# %%
ad = [(k, length(astar(m, hero(m), loc))) for (k, loc) in mkeys(m)]
ad = filter( x -> x[2] > 0, ad)

# %%
find_element(m, 'a')

# %%
m.m[find_element(m, 'a')] = '.'

# %%
@benchmark mkeys($m)

# %%
b = copy(a)

# %%
b[2, 2] = 5

# %%
a

# %%
b

# %%
dirs = CartesianIndex.([(0, 1), (1, 0), (0, -1), (-1, 0)])
#    l .+ dirs[val(m, l + d), allowed(m)) for d in dirs]

# %%
dirs[[val(m, hero(m) + d) in allowed(m) for d in dirs]]

# %%
2 in [3, 4, 2]

# %%
paths = floodfill(m)
available_keys = filter(x -> x[2] > 0, [(k, paths[v]) for (k, v) in mkeys(m)])

# %%
using BenchmarkTools

@benchmark neighbours($m, $hero(m))

# %%
upper(c) = ('A' - 'a') + c

# %%
upper('c')

# %%
fill(-1, size(m.m)...)

# %%
function ff(m)
    me = hero(m)
    available_keys = filter( x -> x[2] > 0, [(k, length(astar(m, hero(m), loc))) for (k, loc) in mkeys(state)])
end

# %%
heur(hdict, c, ks) = sum([v for (k, v) in hdict[c] if k in ks])

# %%
"abc"[end]
